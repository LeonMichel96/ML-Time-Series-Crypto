# %% [markdown]
# # Crypto Currency Time Series Project

# %% [markdown]
# This notebook aims to deliver a tuned ARIMA model capable of predicting price values of some of the most famous
# crypto currencies based on the past data

# %%
import requests
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_predict
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# # Define the API params

# %% [markdown]
# First define the coin to predict, actual date and a past date of n years in the past.
# Lastly define other API params such as currency and number of decimals.

# %%
coin = 'ethereum'

# %%
url = f'https://api.coingecko.com/api/v3/coins/{coin}/market_chart/range'

# %%
years = 2

# %%
today = int(datetime.datetime.now().timestamp())

# %%
past_date = int((datetime.datetime.now() - datetime.timedelta(days=365 * years)).timestamp())

# %%
params = {'vs_currency': 'usd',
          'from': past_date,
          'to': today,
          'precision': 2}

# %%
response = requests.get(url, params=params).json()

# %%
df = pd.DataFrame(response["prices"], columns=["Timestamp", "Price"])
df.head()
# Out:
#        Timestamp    Price
# 0  1637193600000  4302.80
# 1  1637280000000  3993.85
# 2  1637366400000  4317.60
# 3  1637452800000  4436.19
# 4  1637539200000  4319.36

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Change the date table to a more human readable format, from Timestamp to yyyy-mm-dd

# %%
df['Date']= df['Timestamp'].apply(lambda x: datetime.datetime.fromtimestamp(x/1000).strftime("%Y-%m-%d"))

# %%
df['Timestamp'] = df['Date']

# %%
df.drop(columns=['Date'], inplace=True)

# %%
df.rename(columns={'Timestamp': 'Date'}, inplace=True)

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date    Price
# 0 2021-11-17  4302.80
# 1 2021-11-18  3993.85
# 2 2021-11-19  4317.60
# 3 2021-11-20  4436.19
# 4 2021-11-21  4319.36

# %%
df.dtypes
# Out:
# Date     datetime64[ns]
# Price           float64
# dtype: object

# %%
plt.figure(figsize=(10,5))
plt.title(f'{coin} trend')
sns.lineplot(data=df, x='Date', y='Price')
# Out:
# <AxesSubplot:title={'center':'ethereum trend'}, xlabel='Date', ylabel='Price'>

# %% [markdown]
# # SARIMA Grid Search

# %%
df['log'] = np.log(df.Price)

# %%
plt.figure(figsize=(10,5))
plt.title(f'{coin} trend log data')
sns.lineplot(data=df, x='Date', y='log')
# Out:
# <AxesSubplot:title={'center':'ethereum trend log data'}, xlabel='Date', ylabel='log'>

# %%
len(df)
# Out:
# 730

# %% [markdown]
# ## Train Test Split

# %%
train_percentage = int(0.8*(len(df)))

# %%
train_percentage
# Out:
# 584

# %%
# Create train test split
train = df.log[:train_percentage]
test = df.log[train_percentage:]

# %% [markdown]
# ## Testing Stationarity and finding seasonality

# %%
fig, axs = plt.subplots(1, 2, figsize=(18,8))


# Log series
axs[0].plot(df.log); axs[0].set_title('Log Series')

# Normal differencing
axs[1].plot(df.log.diff(1)); axs[1].set_title('1st Order Differencing')
# Out:
# Text(0.5, 1.0, '1st Order Differencing')

# %%
# P Value for trusting stationarity 
adfuller(df.log)[1]  # Original data
# Out:
# 0.12618245246880994

# %%
# P Value for trusting stationarity 
adfuller(df.log.diff(1).dropna())[1]  # First order diff
# Out:
# 4.2295607391513386e-27

# %%
# automatically estimate differencing term
from pmdarima.arima.utils import ndiffs
ndiffs(train)
# Out:
# 1

# %%
price_diff =df.log.diff(1).dropna()

# %%
# ACF / PACF analysis of y_diff linearized
fig, axes = plt.subplots(1,3, figsize=(16,5))
axes[0].plot(price_diff)
axes[0].set_title('First Order Differencing')
plot_acf(price_diff, ax=axes[1]);
plot_pacf(price_diff, ax=axes[2], c='r');

# %%
#Grid Search
smodel = pm.auto_arima(train, seasonal = False, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-2077.851, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-2075.415, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-2073.682, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-2073.680, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-2076.715, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-2070.027, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-2069.690, Time=0.10 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-2070.030, Time=0.21 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-2073.972, Time=0.27 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-2070.212, Time=0.06 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-2075.898, Time=0.23 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-2070.887, Time=0.20 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-2073.553, Time=0.26 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-2079.092, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-2071.336, Time=0.11 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-2075.798, Time=0.13 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-2077.153, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-2072.719, Time=0.04 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-2077.211, Time=0.10 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=-2072.244, Time=0.08 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-2075.846, Time=0.17 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 2.677 seconds

# %%
predictions_sm = smodel.predict(len(test), return_conf_int=True)

# %%
p, d, q = smodel.order

# %% [markdown]
# # Build Model and Predict

# %%
# 1. initialize the model
arima = ARIMA(train, order=(p, d, q))

# 2. fit the models
arima = arima.fit()

arima.summary()
# Out:
# /Users/leonardomichelramirez/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    log   No. Observations:                  584
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                1044.546
# Date:                Thu, 16 Nov 2023   AIC                          -2079.092
# Time:                        23:16:08   BIC                          -2057.251
# Sample:                             0   HQIC                         -2070.579
#                                 - 584
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9217      0.053    -17.432      0.000      -1.025      -0.818
# ar.L2         -0.9358      0.056    -16.586      0.000      -1.046      -0.825
# ma.L1          0.8870      0.067     13.298      0.000       0.756       1.018
# ma.L2          0.8933      0.068     13.143      0.000       0.760       1.027
# sigma2         0.0016   6.04e-05     26.847      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):               285.24
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.40   Skew:                            -0.49
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Statsmodels Forecast

# %%
# Forecast values and confidence intervals
forecast_results = arima.get_forecast(len(test), alpha=0.05)
forecast_stats = forecast_results.predicted_mean
confidence_stats = forecast_results.conf_int().values
# Out:
# /Users/leonardomichelramirez/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/statsmodels/tsa/statespace/representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
confidence_stats
# Out:
# array([[7.46898059, 7.62683539],
#        [7.43655774, 7.65595579],
#        [7.41201169, 7.67818939],
#        [7.39310158, 7.70232135],
#        [7.37393347, 7.71884051],
#        [7.35695143, 7.73337741],
#        [7.34361837, 7.75144307],
#        [7.32867927, 7.76430833],
#        [7.31472598, 7.77574425],
#        [7.30393656, 7.79079465],
#        [7.29134808, 7.80181158],
#        [7.27914566, 7.81147503],
#        [7.26984128, 7.82459024],
#        [7.2588266 , 7.83446849],
#        [7.24781182, 7.84296449],
#        [7.23948201, 7.85467935],
#        [7.22962429, 7.86377418],
#        [7.21949365, 7.8714402 ],
#        [7.21184976, 7.88206964],
#        [7.20289046, 7.89058359],
#        [7.19345957, 7.89763105],
#        [7.1863223 , 7.90738189],
#        [7.17808546, 7.91544025],
#        [7.16923267, 7.92201173],
#        [7.16248365, 7.93103045],
#        [7.15484169, 7.93871531],
#        [7.14648158, 7.94491187],
#        [7.14003934, 7.95330811],
#        [7.13289546, 7.96067567],
#        [7.12496495, 7.96657144],
#        [7.11877176, 7.97443072],
#        [7.11205007, 7.98152091],
#        [7.10450058, 7.9871716 ],
#        [7.09851465, 7.9945628 ],
#        [7.09215419, 8.00140494],
#        [7.08494694, 8.00685316],
#        [7.07913753, 8.01383311],
#        [7.07308846, 8.02044942],
#        [7.06619152, 8.02572813],
#        [7.06053573, 8.0323446 ],
#        [7.05475673, 8.0387525 ],
#        [7.04814315, 8.04388741],
#        [7.04262377, 8.05018115],
#        [7.03708026, 8.05639469],
#        [7.03072676, 8.06140596],
#        [7.02533071, 8.06741212],
#        [7.01999353, 8.07344304],
#        [7.01387967, 8.07834654],
#        [7.00859692, 8.08409566],
#        [7.00344135, 8.08995405],
#        [6.99754892, 8.09476226],
#        [6.99237171, 8.10028109],
#        [6.9873767 , 8.10597585],
#        [6.98168929, 8.11069861],
#        [6.97661154, 8.11601065],
#        [6.97175914, 8.12154984],
#        [6.96626183, 8.12619489],
#        [6.96127867, 8.13132086],
#        [6.95655354, 8.13671192],
#        [6.95123269, 8.14128533],
#        [6.94634018, 8.14624357],
#        [6.94172918, 8.15149345],
#        [6.93657227, 8.156     ],
#        [6.9317671 , 8.16080673],
#        [6.92725899, 8.16592201],
#        [6.92225448, 8.17036544],
#        [6.91753383, 8.17503504],
#        [6.91311897, 8.18002202],
#        [6.90825618, 8.18440525],
#        [6.90361757, 8.18895048],
#        [6.89928771, 8.19381519],
#        [6.89455679, 8.19814052],
#        [6.88999795, 8.20257267],
#        [6.88574602, 8.20732092],
#        [6.88113785, 8.2115902 ],
#        [6.87665666, 8.21591928],
#        [6.87247661, 8.22055667],
#        [6.86798275, 8.22477134],
#        [6.8635772 , 8.22900623],
#        [6.85946384, 8.23353816],
#        [6.85507649, 8.23769943],
#        [6.85074462, 8.24184798],
#        [6.8466935 , 8.24627963],
#        [6.84240544, 8.2503885 ],
#        [6.83814533, 8.25445767],
#        [6.83415263, 8.25879405],
#        [6.82995722, 8.26285138],
#        [6.82576693, 8.26684731],
#        [6.82182937, 8.27109322],
#        [6.81772047, 8.2750998 ],
#        [6.81359811, 8.27902792],
#        [6.80971286, 8.28318795],
#        [6.80568481, 8.28714451],
#        [6.80162845, 8.29100961],
#        [6.79779309, 8.29508817],
#        [6.79384068, 8.2989954 ],
#        [6.78984841, 8.30280173],
#        [6.7860608 , 8.306803  ],
#        [6.78217927, 8.31066161],
#        [6.77824916, 8.3144129 ],
#        [6.77450746, 8.31834086],
#        [6.77069241, 8.32215157],
#        [6.76682255, 8.32585113],
#        [6.76312513, 8.32970957],
#        [6.75937255, 8.33347311],
#        [6.75556103, 8.33712384],
#        [6.75190647, 8.34091635],
#        [6.74821266, 8.34463349],
#        [6.74445758, 8.34823796],
#        [6.74084459, 8.35196793],
#        [6.73720619, 8.35563945],
#        [6.73350569, 8.35919996],
#        [6.72993312, 8.36287057],
#        [6.72634703, 8.36649729],
#        [6.72269927, 8.37001586],
#        [6.71916606, 8.37363012],
#        [6.71562948, 8.3772129 ],
#        [6.71203263, 8.38069132],
#        [6.70853782, 8.38425205],
#        [6.70504816, 8.38779178],
#        [6.70150045, 8.39123164],
#        [6.69804315, 8.39474149],
#        [6.69459807, 8.39823906],
#        [6.69109776, 8.40164182],
#        [6.68767712, 8.40510325],
#        [6.68427447, 8.4085596 ],
#        [6.68081988, 8.41192652],
#        [6.67743509, 8.41534187],
#        [6.6740729 , 8.41875793],
#        [6.6706624 , 8.42209018],
#        [6.6673127 , 8.42546159],
#        [6.66398918, 8.42883832],
#        [6.66062118, 8.43213697],
#        [6.65730582, 8.43546645],
#        [6.65401934, 8.43880482],
#        [6.6506923 , 8.44207081],
#        [6.64741058, 8.44536025],
#        [6.64415964, 8.44866121],
#        [6.64087209, 8.45189543],
#        [6.63762329, 8.45514657],
#        [6.63440651, 8.4584111 ],
#        [6.63115704, 8.46161437],
#        [6.62794048, 8.46482883],
#        [6.6247566 , 8.46805788],
#        [6.62154385, 8.47123096],
#        [6.61835885, 8.47441025]])

# %%
lower_stats = pd.Series(confidence_stats[:,0], index=test.index)
upper_stats = pd.Series(confidence_stats[:,1], index=test.index)

# %%
# Plot
plt.figure(figsize=(10,4), dpi=100)
plt.plot(train, label='training', color='black')
plt.plot(test, label='actual', color='blue', ls='--')
plt.plot(forecast_stats, label='forecast', color='orange')
plt.fill_between(lower_stats.index, lower_stats, upper_stats, color='k', alpha=.15)
plt.title('Forecast vs Actuals log data (Statsmodels Model)')
plt.legend(loc='upper left', fontsize=8);

# %%
# Re-compose back to initial TS

forecast_recons_stats = np.exp(forecast_stats)
train_recons_stats = np.exp(train)
test_recons_stats = np.exp(test)
lower_recons_stats = np.exp(lower_stats)
upper_recons_stats = np.exp(upper_stats)

# %%
# Plot Original TS and forecast
plt.figure(figsize=(10,4), dpi=100)
plt.plot(df.Date[:train_percentage],train_recons_stats, label='training', color='black')
plt.plot(df.Date[train_percentage:],test_recons_stats, label='actual', color='blue', ls='--')
plt.plot(df.Date[train_percentage:],forecast_recons_stats,label='forecast', color='orange')
plt.fill_between(df.Date[train_percentage:], lower_recons_stats, upper_recons_stats, color='k', alpha=.15)
plt.title('Forecast vs Actuals original data (Statsmodels Model)')
plt.legend(loc='upper left', fontsize=8);

# %% [markdown]
# ## pmdarima Forecast

# %%
forecast_pm = predictions_sm[0]

# %%
lower_pm = pd.Series(predictions_sm[1][:,0], index=test.index)
upper_pm = pd.Series(predictions_sm[1][:,1], index=test.index)

# %%
# Plot
plt.figure(figsize=(10,4), dpi=100)
plt.plot(train, label='training', color='black')
plt.plot(test, label='actual', color='blue', ls='--')
plt.plot(forecast_pm, label='forecast', color='orange')
plt.fill_between(lower_pm.index, lower_pm, upper_pm, color='k', alpha=.15)
plt.title('Forecast vs Actuals log data (pmdarima Model)')
plt.legend(loc='upper left', fontsize=8);

# %%
# Re-compose back to initial TS

forecast_recons_pm = np.exp(forecast_pm)
train_recons_pm = np.exp(train)
test_recons_pm = np.exp(test)
lower_recons_pm = np.exp(lower_pm)
upper_recons_pm = np.exp(upper_pm)

# %%
# Plot Original TS and forecast
plt.figure(figsize=(10,4), dpi=100)
plt.plot(df.Date[:train_percentage],train_recons_pm, label='training', color='black')
plt.plot(df.Date[train_percentage:],test_recons_pm, label='actual', color='blue', ls='--')
plt.plot(df.Date[train_percentage:],forecast_recons_pm,label='forecast', color='orange')
plt.fill_between(df.Date[train_percentage:], lower_recons_pm, upper_recons_pm, color='k', alpha=.15)
plt.title('Forecast vs Actuals original data (pmdarima Model)')
plt.legend(loc='upper left', fontsize=8);

# %% [markdown]
# # Evaluate Models with MAPE

# %% [markdown]
# ## Stats Model Evaluation

# %%
mape_stats = mean_absolute_percentage_error(test_recons_stats,forecast_recons_stats)
mape_stats
# Out:
# 0.09146921253404997

# %% [markdown]
# ## pmdarima Model Evaluation

# %%
mape_stats = mean_absolute_percentage_error(test_recons_pm,forecast_recons_pm)
mape_stats
# Out:
# 0.09146921253404997

# %%
forecast_recons_pm
# Out:
# 584    1896.770512
# 585    1893.641108
# 586    1891.452897
# 587    1896.397789
# 588    1893.887723
#           ...
# 725    1893.885290
# 726    1893.883293
# 727    1893.926069
# 728    1893.888511
# 729    1893.883098
# Length: 146, dtype: float64

# %%
forecast_recons_stats
# Out:
# 584    1896.770512
# 585    1893.641108
# 586    1891.452897
# 587    1896.397789
# 588    1893.887723
#           ...
# 725    1893.885290
# 726    1893.883293
# 727    1893.926069
# 728    1893.888511
# 729    1893.883098
# Name: predicted_mean, Length: 146, dtype: float64

# %% [markdown]
# # Final Observations

# %% [markdown]
# Both Models make the exact same forecast for ether crypto currency, however it seems to be a kind of constant forecast with not much peaks going up or even lower values.
